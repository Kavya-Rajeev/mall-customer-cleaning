# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavya-Rajeev/mall-customer-cleaning/blob/main/mall_customer_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#loading the dataset
df=pd.read_csv('/content/Mall_Customers.csv')

# %%
#view dataset
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
#checking for number of null values in each column
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
#check for duplicated values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#standardizing text values
df['Gender'] = df['Gender'].str.capitalize()
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# renaming column headers
df.columns=df.columns.str.strip().str.lower().str.replace(' ','_')
df.columns
# Out:
# Index(['customerid', 'gender', 'age', 'annual_income_(k$)',
#        'spending_score_(1-100)'],
#       dtype='object')

# %%
# checking the datatypes
df.dtypes
# no changes required
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
# cleaned dataset
df
# Out:
#      customerid  gender  age  annual_income_(k$)  spending_score_(1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# saving cleaned dataset
df.to_csv('mall_customers_cleaned.csv', index=False)

# %%
from google.colab import files
files.download('mall_customers_cleaned.csv')
